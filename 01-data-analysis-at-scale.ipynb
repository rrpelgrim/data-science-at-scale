# %% [markdown]
# <p float="center">
#   <img src="images/Coiled-Logo_Horizontal_Black-CMYK.png" alt="Coiled logo" width="350" hspace="10"/>
# </p>

# %% [markdown]
# <p float="center">
#   <img src="images/dask_horizontal_no_pad.svg" alt="Dask logo" width="400" hspace="10" />
# </p>

# %% [markdown]
# # Data Science At Scale
#
# In this notebook, we'll
#
# * Perform a basic analytics workflow on the NYC taxi dataset using Pandas;
# * Scale up this workflow to a dataset that doesn't fit in RAM using Dask;
# * (Optional) Scale out this workflow to leverage a cluster on the Cloud using Coiled.
#
# The workflow is intentionally boring so that we can see the power of scalable data science immediately: we'll load some data and perform some basic analytics.
#
# In the notebooks that follow, we'll jump into more interesting examples, including machine learning.
#
#
# Before scaling up, let's look at a common workflow in Pandas.

# %% [markdown]
# ## 1. Pandas: Convert CSV to Parquet and Engineer a Feature

# %% [markdown]
# <img src="images/pandas-logo.svg" alt="pandas logo" style="width: 500px;"/>
#
# In the following, we'll
#
# * use Pandas to load in part of the NYC taxi dataset from a CSV and
# * compute the average tip as a function of the number of passengers.
#
# If you're following along in Binder, you won't be able to execute the code but you can read it.

# %% [markdown]
# ### Download the data from Amazon

# %%
# !wget https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-{01..12}.csv
# Out:
# --2021-06-28 10:59:57--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-01.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.36.230
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.36.230|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 687088084 (655M) [text/csv]
# Saving to: ‘yellow_tripdata_2019-01.csv’
#
# yellow_tripdata_201 100%[===================>] 655,26M  1,59MB/s    in 6m 19s
#
# 2021-06-28 11:06:18 (1,73 MB/s) - ‘yellow_tripdata_2019-01.csv’ saved [687088084/687088084]
#
# --2021-06-28 11:06:18--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-02.csv
# Reusing existing connection to s3.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 649882828 (620M) [text/csv]
# Saving to: ‘yellow_tripdata_2019-02.csv’
#
# yellow_tripdata_201 100%[===================>] 619,78M  1,35MB/s    in 4m 55s
#
# 2021-06-28 11:11:14 (2,10 MB/s) - ‘yellow_tripdata_2019-02.csv’ saved [649882828/649882828]
#
# --2021-06-28 11:11:14--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-03.csv
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.36.230|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 726201566 (693M) [text/csv]
# Saving to: ‘yellow_tripdata_2019-03.csv’
#
# yellow_tripdata_201 100%[===================>] 692,56M  1,63MB/s    in 4m 52s
#
# 2021-06-28 11:16:06 (2,38 MB/s) - ‘yellow_tripdata_2019-03.csv’ saved [726201566/726201566]
#
# --2021-06-28 11:16:06--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-04.csv
# Reusing existing connection to s3.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 689207122 (657M) [text/csv]
# Saving to: ‘yellow_tripdata_2019-04.csv’
#
# yellow_tripdata_201 100%[===================>] 657,28M  3,04MB/s    in 5m 6s
#
# 2021-06-28 11:21:12 (2,15 MB/s) - ‘yellow_tripdata_2019-04.csv’ saved [689207122/689207122]
#
# --2021-06-28 11:21:12--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-05.csv
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.36.230|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 701538890 (669M) [text/csv]
# Saving to: ‘yellow_tripdata_2019-05.csv’
#
# yellow_tripdata_201 100%[===================>] 669,04M  3,03MB/s    in 4m 26s
#
# 2021-06-28 11:25:39 (2,52 MB/s) - ‘yellow_tripdata_2019-05.csv’ saved [701538890/701538890]
#
# --2021-06-28 11:25:39--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-06.csv
# Reusing existing connection to s3.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 643492154 (614M) [text/csv]
# Saving to: ‘yellow_tripdata_2019-06.csv’
#
# yellow_tripdata_201 100%[===================>] 613,68M  3,66MB/s    in 4m 35s
#
# 2021-06-28 11:30:14 (2,23 MB/s) - ‘yellow_tripdata_2019-06.csv’ saved [643492154/643492154]
#
# --2021-06-28 11:30:14--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-07.csv
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.36.230|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 584387609 (557M) [text/csv]
# Saving to: ‘yellow_tripdata_2019-07.csv’
#
# yellow_tripdata_201 100%[===================>] 557,32M  3,52MB/s    in 3m 45s
#
# 2021-06-28 11:34:00 (2,48 MB/s) - ‘yellow_tripdata_2019-07.csv’ saved [584387609/584387609]
#
# --2021-06-28 11:34:00--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-08.csv
# Reusing existing connection to s3.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 562386202 (536M) [text/csv]
# Saving to: ‘yellow_tripdata_2019-08.csv’
#
# yellow_tripdata_201 100%[===================>] 536,33M  2,51MB/s    in 4m 15s
#
# 2021-06-28 11:38:15 (2,10 MB/s) - ‘yellow_tripdata_2019-08.csv’ saved [562386202/562386202]
#
# --2021-06-28 11:38:15--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-09.csv
# Reusing existing connection to s3.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608973500 (581M) [text/csv]
# Saving to: ‘yellow_tripdata_2019-09.csv’
#
# yellow_tripdata_201 100%[===================>] 580,76M  1022KB/s    in 4m 43s
#
# 2021-06-28 11:42:59 (2,05 MB/s) - ‘yellow_tripdata_2019-09.csv’ saved [608973500/608973500]
#
# --2021-06-28 11:42:59--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-10.csv
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.36.230|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 669168416 (638M) [text/csv]
# Saving to: ‘yellow_tripdata_2019-10.csv’
#
# yellow_tripdata_201 100%[===================>] 638,17M  4,09MB/s    in 4m 57s
#
# 2021-06-28 11:47:57 (2,15 MB/s) - ‘yellow_tripdata_2019-10.csv’ saved [669168416/669168416]
#
# --2021-06-28 11:47:57--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-11.csv
# Reusing existing connection to s3.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 637807959 (608M) [text/csv]
# Saving to: ‘yellow_tripdata_2019-11.csv’
#
# yellow_tripdata_201 100%[===================>] 608,26M  1,49MB/s    in 5m 1s
#
# 2021-06-28 11:52:58 (2,02 MB/s) - ‘yellow_tripdata_2019-11.csv’ saved [637807959/637807959]
#
# --2021-06-28 11:52:58--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-12.csv
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.36.230|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 639108129 (610M) [text/csv]
# Saving to: ‘yellow_tripdata_2019-12.csv’
#
# yellow_tripdata_201 100%[===================>] 609,50M  2,62MB/s    in 4m 15s
#
# 2021-06-28 11:57:14 (2,39 MB/s) - ‘yellow_tripdata_2019-12.csv’ saved [639108129/639108129]
#
# FINISHED --2021-06-28 11:57:14--
# Total wall clock time: 57m 18s
# Downloaded: 12 files, 7,3G in 57m 10s (2,17 MB/s)

# %% [markdown]
# Note: this will take at least several minutes to download the above.

# %%
# Check out head of 1st file
# !head yellow_tripdata_2019-01.csv
# Out:
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,RatecodeID,store_and_fwd_flag,PULocationID,DOLocationID,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount,congestion_surcharge
# 1,2019-01-01 00:46:40,2019-01-01 00:53:20,1,1.50,1,N,151,239,1,7,0.5,0.5,1.65,0,0.3,9.95,
# 1,2019-01-01 00:59:47,2019-01-01 01:18:59,1,2.60,1,N,239,246,1,14,0.5,0.5,1,0,0.3,16.3,
# 2,2018-12-21 13:48:30,2018-12-21 13:52:40,3,.00,1,N,236,236,1,4.5,0.5,0.5,0,0,0.3,5.8,
# 2,2018-11-28 15:52:25,2018-11-28 15:55:45,5,.00,1,N,193,193,2,3.5,0.5,0.5,0,0,0.3,7.55,
# 2,2018-11-28 15:56:57,2018-11-28 15:58:33,5,.00,2,N,193,193,2,52,0,0.5,0,0,0.3,55.55,
# 2,2018-11-28 16:25:49,2018-11-28 16:28:26,5,.00,1,N,193,193,2,3.5,0.5,0.5,0,5.76,0.3,13.31,
# 2,2018-11-28 16:29:37,2018-11-28 16:33:43,5,.00,2,N,193,193,2,52,0,0.5,0,0,0.3,55.55,
# 1,2019-01-01 00:21:28,2019-01-01 00:28:37,1,1.30,1,N,163,229,1,6.5,0.5,0.5,1.25,0,0.3,9.05,
# 1,2019-01-01 00:32:01,2019-01-01 00:45:39,1,3.70,1,N,229,7,1,13.5,0.5,0.5,3.7,0,0.3,18.5,

# %% [markdown]
# ### Investigate data locally with Pandas

# %%
# %%time
# Import pandas and read in beginning of 1st file
import pandas as pd
df = pd.read_csv(
    "../taxi_data/yellow_tripdata_2019-01.csv", 
    nrows=10000,
)
df
# Out:
# CPU times: user 32.6 s, sys: 11.6 s, total: 44.2 s
# Wall time: 59.1 s
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1               1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2               2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3               2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4               2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
# ...           ...                  ...                   ...              ...
# 7667787         2  2019-01-31 23:57:36   2019-02-01 00:18:39                1
# 7667788         2  2019-01-31 23:32:03   2019-01-31 23:33:11                1
# 7667789         2  2019-01-31 23:36:36   2019-01-31 23:36:40                1
# 7667790         2  2019-01-31 23:14:53   2019-01-31 23:15:20                1
# 7667791         2  2019-01-31 23:12:49   2019-01-31 23:14:08                1
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.50           1                  N           151
# 1                 2.60           1                  N           239
# 2                 0.00           1                  N           236
# 3                 0.00           1                  N           193
# 4                 0.00           2                  N           193
# ...                ...         ...                ...           ...
# 7667787           4.79           1                  N           263
# 7667788           0.00           1                  N           193
# 7667789           0.00           1                  N           264
# 7667790           0.00           1                  N           264
# 7667791           0.00           1                  N           193
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                 239             1          7.0    0.5      0.5        1.65
# 1                 246             1         14.0    0.5      0.5        1.00
# 2                 236             1          4.5    0.5      0.5        0.00
# 3                 193             2          3.5    0.5      0.5        0.00
# 4                 193             2         52.0    0.0      0.5        0.00
# ...               ...           ...          ...    ...      ...         ...
# 7667787             4             1         18.0    0.5      0.5        3.86
# 7667788           193             1          0.0    0.0      0.0        0.00
# 7667789           264             1          0.0    0.0      0.0        0.00
# 7667790             7             1          0.0    0.0      0.0        0.00
# 7667791           193             1          0.0    0.0      0.0        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                 0.0                    0.3          9.95
# 1                 0.0                    0.3         16.30
# 2                 0.0                    0.3          5.80
# 3                 0.0                    0.3          7.55
# 4                 0.0                    0.3         55.55
# ...               ...                    ...           ...
# 7667787           0.0                    0.3         23.16
# 7667788           0.0                    0.0          0.00
# 7667789           0.0                    0.0          0.00
# 7667790           0.0                    0.0          0.00
# 7667791           0.0                    0.0          0.00
#
#          congestion_surcharge
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 7667787                   0.0
# 7667788                   0.0
# 7667789                   0.0
# 7667790                   0.0
# 7667791                   0.0
#
# [7667792 rows x 18 columns]

# %% [markdown]
# ## Basic Analytics

# %%
# %%time

# Compute average tip as a function of the number of passengers
df.groupby("passenger_count").tip_amount.mean()
# Out:
# CPU times: user 11.8 ms, sys: 9 ms, total: 20.8 ms
# Wall time: 69 ms
# passenger_count
# 0    1.719027
# 1    1.667853
# 2    1.829683
# 3    1.709951
# 4    1.688510
# 5    1.840508
# 6    1.836183
# Name: tip_amount, dtype: float64

# %% [markdown]
# **Recap:** We have
#
# * used Pandas to load in part of the NYC taxi dataset from a CSV and
# * computed the average tip as a function of the number of passengers.

# %% [markdown]
# ### Operate on many files in a for loop?
#
# We could do this, but it's unpleasant

# %% [markdown]
# ```python
# for filename in glob("~/data/nyctaxi/yellow_tripdata_2019-*.csv"):
#     df = pd.read_csv(filename)
#     ...
#     df.to_parquet(...)
# ```

# %% [markdown]
# ## 2. Use Dask locally to process the full dataset

# %% [markdown]
# <img src="images/dask_horizontal_no_pad.svg" alt="Dask logo" style="width: 500px;"/>
#
# The full NYC taxi dataset won't even fit in the RAM of my laptop. Do I need a large or external cluster yet? No. First, I can take advantage of all the cores on my laptop in parallel. This is what we call *scaling up* our computation (out-of-core computing). Later we'll see how to *scale out* computation across a cluster.
#
# One way of doing this is with [Dask](dask.org/). As we're about to see, part of the value of Dask lies in its API being as close as possible to the PyData APIs we know and love, in this case, Pandas.
#
# In [the words of Matthew Rocklin](https://coiled.io/blog/history-dask/), core developer and co-maintainer of Dask and CEO of Coiled, there was a social goal of Dask:
# > Invent nothing. We wanted to be as familiar as possible to what users already knew in the PyData stack
#
# Let's do it!
#
# The plan:
#
# * use Dask to load in **all** of the NYC taxi dataset from 10+ CSVs (8+ GBs) and
# * compute the average tip as a function of the number of passengers.

# %% [markdown]
# We'll also dive into the basics of Dask and distributed compute (but we'll execute some code first and dive into this part while it runs!).

# %%
# Import Dask parts, spin up a local cluster, and instantiate a Client
from dask.distributed import LocalCluster, Client
cluster = LocalCluster(n_workers=4)
client = Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:51144' processes=4 threads=4, memory=4.00 GiB>

# %%
# %%time

import dask.dataframe as dd

# Import the full dataset (note the Dask API!)
df = dd.read_csv(
    "yellow_tripdata_2019-*.csv", 
    parse_dates=["tpep_pickup_datetime", "tpep_dropoff_datetime"],
    dtype={'RatecodeID': 'float64',
       'VendorID': 'float64',
       'passenger_count': 'float64',
       'payment_type': 'float64'}

)
df
# Out:
# CPU times: user 59.1 ms, sys: 29.9 ms, total: 89.1 ms
# Wall time: 164 ms
# Dask DataFrame Structure:
#                 VendorID tpep_pickup_datetime tpep_dropoff_datetime passenger_count trip_distance RatecodeID store_and_fwd_flag PULocationID DOLocationID payment_type fare_amount    extra  mta_tax tip_amount tolls_amount improvement_surcharge total_amount congestion_surcharge
# npartitions=127
#                  float64       datetime64[ns]        datetime64[ns]         float64       float64    float64             object        int64        int64      float64     float64  float64  float64    float64      float64               float64      float64              float64
#                      ...                  ...                   ...             ...           ...        ...                ...          ...          ...          ...         ...      ...      ...        ...          ...                   ...          ...                  ...
# ...                  ...                  ...                   ...             ...           ...        ...                ...          ...          ...          ...         ...      ...      ...        ...          ...                   ...          ...                  ...
#                      ...                  ...                   ...             ...           ...        ...                ...          ...          ...          ...         ...      ...      ...        ...          ...                   ...          ...                  ...
#                      ...                  ...                   ...             ...           ...        ...                ...          ...          ...          ...         ...      ...      ...        ...          ...                   ...          ...                  ...
# Dask Name: read-csv, 127 tasks

# %%
# %%time

# Prepare to compute the average tip 
# as a function of the number of passengers
mean_amount = df.groupby("passenger_count").tip_amount.mean()
# Out:
# CPU times: user 29.9 ms, sys: 5.15 ms, total: 35 ms
# Wall time: 49.6 ms

# %%
# %%time

# compute the average tip as a function of the number of passengers
mean_amount.compute()
# Out:
# CPU times: user 2min 4s, sys: 14.8 s, total: 2min 19s
# Wall time: 8min 21s
# passenger_count
# 0.0    2.122789
# 1.0    2.206790
# 2.0    2.214306
# 3.0    2.137775
# 4.0    2.023804
# 5.0    2.235441
# 6.0    2.221105
# 7.0    6.675962
# 8.0    7.111625
# 9.0    7.377822
# Name: tip_amount, dtype: float64

# %% [markdown]
# ### 2a Notes on what is happening in Dask and Python

# %% [markdown]
# The above code will take some time to run so let's take this opportunity to see what is going on with Dask, Python, and the distributed computation.

# %% [markdown]
# #### Components of Dask

# %% [markdown]
# Dask contains 3 main components and we have already seen two of them above:
# * High-level collections in the form of Dask DataFrames (these set up the steps of your computation);
# * Schedulers (these actually execute the computation, in this case, on a single machine).
#
# Let's get a sense for what these are.

# %% [markdown]
# <img src="images/dask-components.svg" width="400px">

# %% [markdown]
# #### Dask DataFrames

# %% [markdown]
# What exactly is this Dask DataFrame? A schematic is worth a thousand words:

# %% [markdown]
# <img src="images/dask-dataframe.svg" width="400px">

# %% [markdown]
# Essentially, the Dask DataFrame is a large, virtual dataframe divided along the index into multiple Pandas DataFrames.

# %% [markdown]
# #### Dask Schedulers, Workers, and beyond

# %% [markdown]
# <img src="images/dask-cluster.svg" width="400px">

# %% [markdown]
# Work (Python code) is performed on a cluster, which consists of
# * a _scheduler_ (which manages and sends the work / tasks to the workers)
# * _workers_, which compute the tasks.
#
# The _client_ is "the user-facing entry point for cluster users." What this means is that the client lives wherever you are writing your Python code and the client talks to the scheduler, passing it the tasks.
#
# **More Resources**
# - tutorial.dask.org
# - Dask Summit videos (TBD), such as the first 10min. of [this talk]()
# - See how Dask is used to solve real-world problems, such as XX and the fight against Covid-19 (TBD)

# %% [markdown]
# **Recap:** We have
#
# * used Dask to load in **all** of the NYC taxi dataset from 10+ CSVs (8+ GBs),
# * computed the average tip as a function of the number of passengers, and
# * dived into the basic of Dask and distributed compute and understand the basic concepts.

# %% [markdown]
# ## 3. Optional: Work directly from the cloud with Coiled
#
# <br>
# <img src="images/Coiled-Logo_Horizontal_Black-CMYK.png" alt="Coiled logo" style="width: 500px;"/>
# <br>
#
# Here I'll spin up a cluster on Coiled to show you just how easy it can be. Note that to do so, I've:
# 1. signed into the [Coiled Free tier](https://coiled.io/product),
# 2. pip installed `coiled`, and
# 3. authenticated.
#
# You can do the same!
#
# The plan:
#
# * use Coiled to load in **all** of the NYC taxi dataset from 10+ CSVs (8+ GBs) on an AWS cluster,
# * massage the data,
# * engineer a feature,
# * compute the average tip as a function of the number of passengers, and
# * save to [Parquet](https://en.wikipedia.org/wiki/Apache_Parquet) (far more efficient than CSV, but not human-readable).

# %%
import coiled
from dask.distributed import LocalCluster, Client

# %% [markdown]
# To set up a Coiled cluster takes just 4 simple steps:
# 1. Create a software environment (saved to your account for later use)
# 2. Create a cluster configuration (saved to your account for later use)
# 3. Spin up the cluster
# 4. Connect cluster to Dask client

# %%
# %%time

# Create a Software Environment
coiled.create_software_environment(
    name="my-software-env",
    conda="binder/environment.yml",
)
# Out:
# Updating software environment...
# Creating new software environment
# Creating new ecr build
# STEP 1: FROM coiled/default:sha-6b4e896
# STEP 2: COPY environment.yml environment.yml
# --> 76321a813e2
# STEP 3: RUN conda env update -n coiled -f environment.yml     && rm environment.yml     && conda clean --all -y     && echo "conda activate coiled" >> ~/.bashrc
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
# openjpeg-2.4.0       | 444 KB    | ########## | 100%
# xorg-libxrender-0.9. | 32 KB     | ########## | 100%
# nbformat-5.1.3       | 47 KB     | ########## | 100%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
# pyqt5-sip-4.19.18    | 310 KB    | ########## | 100%
# xorg-libice-1.0.10   | 58 KB     | ########## | 100%
# click-8.0.1          | 146 KB    | ########## | 100%
# pexpect-4.8.0        | 47 KB     | ########## | 100%
# mysql-common-8.0.25  | 1.6 MB    | ########## | 100%
# zeromq-4.3.4         | 352 KB    | ########## | 100%
# psutil-5.8.0         | 342 KB    | ########## | 100%
# ncurses-6.2          | 985 KB    | ########## | 100%
# libuuid-2.32.1       | 28 KB     | ########## | 100%
# openssl-1.1.1k       | 2.1 MB    | ########## | 100%
# libwebp-base-1.2.0   | 815 KB    | ########## | 100%
# terminado-0.10.1     | 26 KB     | ########## | 100%
# krb5-1.19.1          | 1.4 MB    | ########## | 100%
# libwebp-1.2.0        | 85 KB     | ########## | 100%
# fsspec-2021.6.1      | 79 KB     | ########## | 100%
# wrapt-1.12.1         | 47 KB     | ########## | 100%
# jedi-0.18.0          | 937 KB    | ########## | 100%
# testpath-0.5.0       | 86 KB     | ########## | 100%
# libopus-1.3.1        | 255 KB    | ########## | 100%
# atk-1.0-2.36.0       | 560 KB    | ########## | 100%
# librsvg-2.50.7       | 17.0 MB   | ########## | 100%
# pthread-stubs-0.4    | 5 KB      | ########## | 100%
# qt-5.12.9            | 99.5 MB   | ########## | 100%
# snappy-1.1.8         | 32 KB     | ########## | 100%
# prompt-toolkit-3.0.1 | 244 KB    | ########## | 100%
# bzip2-1.0.8          | 484 KB    | ########## | 100%
# toolz-0.11.1         | 46 KB     | ########## | 100%
# h5py-3.3.0           | 1.4 MB    | ########## | 100%
# rich-10.4.0          | 339 KB    | ########## | 100%
# pyrsistent-0.17.3    | 90 KB     | ########## | 100%
# s3fs-2021.6.1        | 25 KB     | ########## | 100%
# libgcc-ng-9.3.0      | 7.8 MB    | ########## | 100%
# libutf8proc-2.6.1    | 95 KB     | ########## | 100%
# scikit-learn-0.24.2  | 7.6 MB    | ########## | 100%
# pyqtwebengine-5.12.1 | 175 KB    | ########## | 100%
# readline-8.1         | 295 KB    | ########## | 100%
# nbclassic-0.3.1      | 18 KB     | ########## | 100%
# pickleshare-0.7.5    | 9 KB      | ########## | 100%
# dask-2021.6.2        | 4 KB      | ########## | 100%
# fonts-conda-forge-1  | 4 KB      | ########## | 100%
# nspr-4.30            | 233 KB    | ########## | 100%
# future-0.18.2        | 712 KB    | ########## | 100%
# s2n-1.0.10           | 442 KB    | ########## | 100%
# pyzmq-22.1.0         | 525 KB    | ########## | 100%
# glog-0.5.0           | 104 KB    | ########## | 100%
# dbus-1.13.6          | 572 KB    | ########## | 100%
# numba-0.53.1         | 3.7 MB    | ########## | 100%
# gdk-pixbuf-2.42.6    | 609 KB    | ########## | 100%
# jupyterlab_pygments- | 8 KB      | ########## | 100%
# grpc-cpp-1.38.1      | 3.6 MB    | ########## | 100%
# zict-2.0.0           | 10 KB     | ########## | 100%
# distributed-2021.6.2 | 1.2 MB    | ########## | 100%
# ptyprocess-0.7.0     | 16 KB     | ########## | 100%
# pyqt-5.12.3          | 21 KB     | ########## | 100%
# entrypoints-0.3      | 8 KB      | ########## | 100%
# parso-0.8.2          | 68 KB     | ########## | 100%
# zlib-1.2.11          | 106 KB    | ########## | 100%
# pixman-0.40.0        | 627 KB    | ########## | 100%
# gst-plugins-base-1.1 | 2.6 MB    | ########## | 100%
# libev-4.33           | 104 KB    | ########## | 100%
# lerc-2.2.1           | 213 KB    | ########## | 100%
# cycler-0.10.0        | 9 KB      | ########## | 100%
# ca-certificates-2021 | 136 KB    | ########## | 100%
# webencodings-0.5.1   | 12 KB     | ########## | 100%
# glib-2.68.3          | 449 KB    | ########## | 100%
# pandoc-2.14.0.3      | 12.0 MB   | ########## | 100%
# async-timeout-3.0.1  | 11 KB     | ########## | 100%
# libblas-3.9.0        | 11 KB     | ########## | 100%
# pyarrow-4.0.1        | 2.7 MB    | ########## | 100%
# brotlipy-0.7.0       | 341 KB    | ########## | 100%
# libpng-1.6.37        | 306 KB    | ########## | 100%
# abseil-cpp-20210324. | 1010 KB   | ########## | 100%
# nbclient-0.5.3       | 67 KB     | ########## | 100%
# libogg-1.3.4         | 206 KB    | ########## | 100%
# xorg-kbproto-1.0.7   | 27 KB     | ########## | 100%
# aioitertools-0.7.1   | 19 KB     | ########## | 100%
# cryptography-3.4.7   | 1.1 MB    | ########## | 100%
# freetype-2.10.4      | 890 KB    | ########## | 100%
# libffi-3.3           | 51 KB     | ########## | 100%
# glib-tools-2.68.3    | 86 KB     | ########## | 100%
# backports.functools_ | 9 KB      | ########## | 100%
# pyqtchart-5.12       | 257 KB    | ########## | 100%
# pandocfilters-1.4.2  | 9 KB      | ########## | 100%
# python_abi-3.8       | 4 KB      | ########## | 100%
# jbig-2.1             | 43 KB     | ########## | 100%
# lzo-2.10             | 314 KB    | ########## | 100%
# xorg-libxau-1.0.9    | 13 KB     | ########## | 100%
# cached_property-1.5. | 11 KB     | ########## | 100%
# locket-0.2.0         | 6 KB      | ########## | 100%
# pycparser-2.20       | 94 KB     | ########## | 100%
# ipython-7.25.0       | 1.1 MB    | ########## | 100%
# setuptools-49.6.0    | 929 KB    | ########## | 100%
# liblapack-3.9.0      | 11 KB     | ########## | 100%
# matplotlib-inline-0. | 11 KB     | ########## | 100%
# joblib-1.0.1         | 206 KB    | ########## | 100%
# python-dateutil-2.8. | 220 KB    | ########## | 100%
# libnghttp2-1.43.0    | 808 KB    | ########## | 100%
# botocore-1.20.49     | 4.6 MB    | ########## | 100%
# nodejs-14.15.4       | 15.7 MB   | ########## | 100%
# libgomp-9.3.0        | 376 KB    | ########## | 100%
# zipp-3.4.1           | 11 KB     | ########## | 100%
# xorg-xextproto-7.3.0 | 28 KB     | ########## | 100%
# aiohttp-3.7.4.post0  | 641 KB    | ########## | 100%
# libclang-11.1.0      | 19.2 MB   | ########## | 100%
# pandas-1.2.5         | 12.1 MB   | ########## | 100%
# fonts-conda-ecosyste | 4 KB      | ########## | 100%
# libuv-1.41.0         | 1.0 MB    | ########## | 100%
# nss-3.67             | 2.1 MB    | ########## | 100%
# arrow-cpp-4.0.1      | 22.2 MB   | ########## | 100%
# yarl-1.6.3           | 143 KB    | ########## | 100%
# llvmlite-0.36.0      | 2.8 MB    | ########## | 100%
# matplotlib-3.4.2     | 7 KB      | ########## | 100%
# async_generator-1.10 | 18 KB     | ########## | 100%
# libgfortran5-9.3.0   | 2.0 MB    | ########## | 100%
# alsa-lib-1.2.3       | 560 KB    | ########## | 100%
# xorg-libxext-1.3.4   | 54 KB     | ########## | 100%
# xorg-renderproto-0.1 | 9 KB      | ########## | 100%
# pillow-8.2.0         | 688 KB    | ########## | 100%
# aws-sdk-cpp-1.8.186  | 4.6 MB    | ########## | 100%
# importlib-metadata-4 | 31 KB     | ########## | 100%
# jupyter_core-4.7.1   | 72 KB     | ########## | 100%
# jsonschema-3.2.0     | 45 KB     | ########## | 100%
# xorg-libsm-1.2.3     | 26 KB     | ########## | 100%
# argon2-cffi-20.1.0   | 48 KB     | ########## | 100%
# dask-labextension-5. | 38 KB     | ########## | 100%
# jmespath-0.10.0      | 21 KB     | ########## | 100%
# backports-1.0        | 4 KB      | ########## | 100%
# libevent-2.1.10      | 1.1 MB    | ########## | 100%
# pip-21.1.3           | 1.1 MB    | ########## | 100%
# libopenblas-0.3.15   | 9.2 MB    | ########## | 100%
# requests-unixsocket- | 14 KB     | ########## | 100%
# libxml2-2.9.12       | 772 KB    | ########## | 100%
# graphviz-2.47.3      | 4.0 MB    | ########## | 100%
# giflib-5.2.1         | 77 KB     | ########## | 100%
# multidict-5.1.0      | 68 KB     | ########## | 100%
# font-ttf-source-code | 684 KB    | ########## | 100%
# fribidi-1.0.10       | 112 KB    | ########## | 100%
# libpq-13.3           | 2.7 MB    | ########## | 100%
# pyparsing-2.4.7      | 60 KB     | ########## | 100%
# kiwisolver-1.3.1     | 80 KB     | ########## | 100%
# cytoolz-0.11.0       | 420 KB    | ########## | 100%
# idna-2.10            | 52 KB     | ########## | 100%
# yaml-0.2.5           | 82 KB     | ########## | 100%
# libtiff-4.3.0        | 668 KB    | ########## | 100%
# re2-2021.06.01       | 218 KB    | ########## | 100%
# pysocks-1.7.1        | 27 KB     | ########## | 100%
# pyqt-impl-5.12.3     | 5.9 MB    | ########## | 100%
# libllvm10-10.0.1     | 26.4 MB   | ########## | 100%
# anyio-3.2.1          | 139 KB    | ########## | 100%
# sortedcontainers-2.4 | 26 KB     | ########## | 100%
# babel-2.9.1          | 6.2 MB    | ########## | 100%
# dask-glm-0.2.0       | 14 KB     | ########## | 100%
# coiled-0.0.39.1      | 53 KB     | ########## | 100%
# expat-2.4.1          | 182 KB    | ########## | 100%
# gettext-0.19.8.1     | 3.6 MB    | ########## | 100%
# ld_impl_linux-64-2.3 | 618 KB    | ########## | 100%
# attrs-21.2.0         | 44 KB     | ########## | 100%
# gts-0.7.6            | 411 KB    | ########## | 100%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
# sqlite-3.36.0        | 1.4 MB    | ########## | 100%
# cloudpickle-1.6.0    | 22 KB     | ########## | 100%
# ipykernel-5.5.5      | 167 KB    | ########## | 100%
# pyopenssl-20.0.1     | 48 KB     | ########## | 100%
# libdeflate-1.7       | 67 KB     | ########## | 100%
# decorator-5.0.9      | 11 KB     | ########## | 100%
# hdf5-1.10.6          | 3.1 MB    | ########## | 100%
# mistune-0.8.4        | 54 KB     | ########## | 100%
# pango-1.48.5         | 398 KB    | ########## | 100%
# libstdcxx-ng-9.3.0   | 4.0 MB    | ########## | 100%
# jupyter_server-1.9.0 | 262 KB    | ########## | 100%
# libedit-3.1.20191231 | 121 KB    | ########## | 100%
# pcre-8.45            | 253 KB    | ########## | 100%
# jpeg-9d              | 264 KB    | ########## | 100%
# bokeh-2.3.2          | 8.2 MB    | ########## | 100%
# lcms2-2.12           | 443 KB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# threadpoolctl-2.1.0  | 15 KB     | ########## | 100%
# libgd-2.3.2          | 299 KB    | ########## | 100%
# typing_extensions-3. | 28 KB     | ########## | 100%
# lz4-c-1.9.3          | 179 KB    | ########## | 100%
# libprotobuf-3.16.0   | 2.5 MB    | ########## | 100%
# libvorbis-1.3.7      | 280 KB    | ########## | 100%
# urllib3-1.26.6       | 99 KB     | ########## | 100%
# wcwidth-0.2.5        | 33 KB     | ########## | 100%
# python-3.8.10        | 26.2 MB   | ########## | 100%
# notebook-6.4.0       | 6.1 MB    | ########## | 100%
# jupyterlab_server-2. | 44 KB     | ########## | 100%
# send2trash-1.7.1     | 17 KB     | ########## | 100%
# mock-4.0.3           | 51 KB     | ########## | 100%
# gflags-2.2.2         | 114 KB    | ########## | 100%
# libsodium-1.0.18     | 366 KB    | ########## | 100%
# aws-c-event-stream-0 | 47 KB     | ########## | 100%
# backcall-0.2.0       | 13 KB     | ########## | 100%
# aiobotocore-1.3.1    | 40 KB     | ########## | 100%
# libxcb-1.13          | 395 KB    | ########## | 100%
# xorg-xproto-7.0.31   | 73 KB     | ########## | 100%
# gtk2-2.24.33         | 7.3 MB    | ########## | 100%
# font-ttf-inconsolata | 94 KB     | ########## | 100%
# json5-0.9.5          | 20 KB     | ########## | 100%
# harfbuzz-2.8.1       | 1.9 MB    | ########## | 100%
# traitlets-5.0.5      | 81 KB     | ########## | 100%
# brotli-1.0.9         | 389 KB    | ########## | 100%
# font-ttf-dejavu-sans | 388 KB    | ########## | 100%
# mysql-libs-8.0.25    | 1.8 MB    | ########## | 100%
# defusedxml-0.7.1     | 23 KB     | ########## | 100%
# matplotlib-base-3.4. | 7.2 MB    | ########## | 100%
# gstreamer-1.18.4     | 2.0 MB    | ########## | 100%
# numpy-1.21.0         | 6.2 MB    | ########## | 100%
# jupyterlab-3.0.16    | 5.7 MB    | ########## | 100%
# jinja2-3.0.1         | 99 KB     | ########## | 100%
# libtool-2.4.6        | 497 KB    | ########## | 100%
# libthrift-0.14.2     | 4.5 MB    | ########## | 100%
# tblib-1.7.0          | 15 KB     | ########## | 100%
# libiconv-1.16        | 1.4 MB    | ########## | 100%
# libcurl-7.77.0       | 334 KB    | ########## | 100%
# aws-checksums-0.1.11 | 50 KB     | ########## | 100%
# xorg-libx11-1.7.2    | 941 KB    | ########## | 100%
# zstd-1.5.0           | 490 KB    | ########## | 100%
# pytables-3.6.1       | 1.5 MB    | ########## | 100%
# s3transfer-0.3.7     | 51 KB     | ########## | 100%
# olefile-0.46         | 32 KB     | ########## | 100%
# font-ttf-ubuntu-0.83 | 1.9 MB    | ########## | 100%
# aws-c-common-0.6.2   | 168 KB    | ########## | 100%
# requests-2.25.1      | 51 KB     | ########## | 100%
# nbconvert-6.1.0      | 521 KB    | ########## | 100%
# libssh2-1.9.0        | 226 KB    | ########## | 100%
# websocket-client-0.5 | 59 KB     | ########## | 100%
# nomkl-1.0            | 4 KB      | ########## | 100%
# six-1.16.0           | 14 KB     | ########## | 100%
# numexpr-2.7.3        | 201 KB    | ########## | 100%
# packaging-20.9       | 35 KB     | ########## | 100%
# boto3-1.17.49        | 70 KB     | ########## | 100%
# wheel-0.36.2         | 31 KB     | ########## | 100%
# libglib-2.68.3       | 3.1 MB    | ########## | 100%
# jupyter_client-6.1.1 | 79 KB     | ########## | 100%
# dask-ml-1.9.0        | 101 KB    | ########## | 100%
# nest-asyncio-1.5.1   | 9 KB      | ########## | 100%
# typing-extensions-3. | 8 KB      | ########## | 100%
# cffi-1.14.5          | 227 KB    | ########## | 100%
# dask-core-2021.6.2   | 743 KB    | ########## | 100%
# cairo-1.16.0         | 1.5 MB    | ########## | 100%
# xz-5.2.5             | 343 KB    | ########## | 100%
# markupsafe-2.0.1     | 22 KB     | ########## | 100%
# graphite2-1.3.13     | 102 KB    | ########## | 100%
# libcblas-3.9.0       | 11 KB     | ########## | 100%
# ipython_genutils-0.2 | 21 KB     | ########## | 100%
# simpervisor-0.4      | 9 KB      | ########## | 100%
# c-ares-1.17.1        | 109 KB    | ########## | 100%
# scipy-1.7.0          | 21.9 MB   | ########## | 100%
# sniffio-1.2.0        | 15 KB     | ########## | 100%
# parquet-cpp-1.5.1    | 3 KB      | ########## | 100%
# jupyter-server-proxy | 27 KB     | ########## | 100%
# blosc-1.21.0         | 841 KB    | ########## | 100%
# certifi-2021.5.30    | 141 KB    | ########## | 100%
# xorg-libxdmcp-1.1.3  | 19 KB     | ########## | 100%
# multipledispatch-0.6 | 12 KB     | ########## | 100%
# prometheus_client-0. | 46 KB     | ########## | 100%
# orc-1.6.8            | 740 KB    | ########## | 100%
# commonmark-0.9.1     | 46 KB     | ########## | 100%
# bleach-3.3.0         | 111 KB    | ########## | 100%
# icu-68.1             | 13.0 MB   | ########## | 100%
# fontconfig-2.13.1    | 357 KB    | ########## | 100%
# msgpack-python-1.0.2 | 92 KB     | ########## | 100%
# pytz-2021.1          | 239 KB    | ########## | 100%
# partd-1.2.0          | 18 KB     | ########## | 100%
# aws-c-io-0.10.5      | 121 KB    | ########## | 100%
# libllvm11-11.1.0     | 29.1 MB   | ########## | 100%
# tornado-6.1          | 649 KB    | ########## | 100%
# libgfortran-ng-9.3.0 | 22 KB     | ########## | 100%
# cached-property-1.5. | 4 KB      | ########## | 100%
# libxkbcommon-1.0.3   | 581 KB    | ########## | 100%
# chardet-4.0.0        | 199 KB    | ########## | 100%
# pygments-2.9.0       | 754 KB    | ########## | 100%
# python-graphviz-0.16 | 20 KB     | ########## | 100%
# nbserverproxy-0.8.8  | 10 KB     | ########## | 100%
# pyyaml-5.4.1         | 192 KB    | ########## | 100%
# aws-c-cal-0.5.11     | 37 KB     | ########## | 100%
# heapdict-1.0.1       | 7 KB      | ########## | 100%
# colorama-0.4.4       | 18 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate coiled
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Cache location: /opt/conda/pkgs
# Will remove the following tarballs:
#
# /opt/conda/pkgs
# ---------------
# openjpeg-2.4.0-hb52868f_1.tar.bz2            444 KB
# xorg-libxrender-0.9.10-h7f98852_1003.tar.bz2      32 KB
# nbformat-5.1.3-pyhd8ed1ab_0.tar.bz2           47 KB
# _libgcc_mutex-0.1-conda_forge.tar.bz2          3 KB
# pyqt5-sip-4.19.18-py38h709712a_7.tar.bz2     310 KB
# xorg-libice-1.0.10-h7f98852_0.tar.bz2         58 KB
# click-8.0.1-py38h578d9bd_0.tar.bz2           146 KB
# pexpect-4.8.0-pyh9f0ad1d_2.tar.bz2            47 KB
# mysql-common-8.0.25-ha770c72_2.tar.bz2       1.6 MB
# zeromq-4.3.4-h9c3ff4c_0.tar.bz2              352 KB
# psutil-5.8.0-py38h497a2fe_1.tar.bz2          342 KB
# ncurses-6.2-h58526e2_4.tar.bz2               985 KB
# libuuid-2.32.1-h7f98852_1000.tar.bz2          28 KB
# openssl-1.1.1k-h7f98852_0.tar.bz2            2.1 MB
# libwebp-base-1.2.0-h7f98852_2.tar.bz2        815 KB
# terminado-0.10.1-py38h578d9bd_0.tar.bz2       26 KB
# krb5-1.19.1-hcc1bbae_0.tar.bz2               1.4 MB
# libwebp-1.2.0-h3452ae3_0.tar.bz2              85 KB
# fsspec-2021.6.1-pyhd8ed1ab_0.tar.bz2          79 KB
# wrapt-1.12.1-py38h497a2fe_3.tar.bz2           47 KB
# jedi-0.18.0-py38h578d9bd_2.tar.bz2           937 KB
# testpath-0.5.0-pyhd8ed1ab_0.tar.bz2           86 KB
# libopus-1.3.1-h7f98852_1.tar.bz2             255 KB
# atk-1.0-2.36.0-h3371d22_4.tar.bz2            560 KB
# librsvg-2.50.7-hc3c00ef_0.tar.bz2           17.0 MB
# pthread-stubs-0.4-h36c2ea0_1001.tar.bz2        5 KB
# qt-5.12.9-hda022c4_4.tar.bz2                99.5 MB
# snappy-1.1.8-he1b5a44_3.tar.bz2               32 KB
# prompt-toolkit-3.0.19-pyha770c72_0.tar.bz2     244 KB
# bzip2-1.0.8-h7f98852_4.tar.bz2               484 KB
# toolz-0.11.1-py_0.tar.bz2                     46 KB
# h5py-3.3.0-nompi_py38h9915d05_100.tar.bz2     1.4 MB
# rich-10.4.0-py38h578d9bd_0.tar.bz2           339 KB
# pyrsistent-0.17.3-py38h497a2fe_2.tar.bz2      90 KB
# s3fs-2021.6.1-pyhd8ed1ab_0.tar.bz2            25 KB
# libgcc-ng-9.3.0-h2828fa1_19.tar.bz2          7.8 MB
# libutf8proc-2.6.1-h7f98852_0.tar.bz2          95 KB
# scikit-learn-0.24.2-py38hdc147b9_0.tar.bz2     7.6 MB
# pyqtwebengine-5.12.1-py38h7400c14_7.tar.bz2     175 KB
# readline-8.1-h46c0cb4_0.tar.bz2              295 KB
# nbclassic-0.3.1-pyhd8ed1ab_1.tar.bz2          18 KB
# pickleshare-0.7.5-py_1003.tar.bz2              9 KB
# dask-2021.6.2-pyhd8ed1ab_0.tar.bz2             4 KB
# fonts-conda-forge-1-0.tar.bz2                  4 KB
# nspr-4.30-h9c3ff4c_0.tar.bz2                 233 KB
# future-0.18.2-py38h578d9bd_3.tar.bz2         712 KB
# s2n-1.0.10-h9b69904_0.tar.bz2                442 KB
# pyzmq-22.1.0-py38h2035c66_0.tar.bz2          525 KB
# glog-0.5.0-h48cff8f_0.tar.bz2                104 KB
# dbus-1.13.6-h48d8840_2.tar.bz2               572 KB
# numba-0.53.1-py38h8b71fd7_1.tar.bz2          3.7 MB
# gdk-pixbuf-2.42.6-h04a7f16_0.tar.bz2         609 KB
# jupyterlab_pygments-0.1.2-pyh9f0ad1d_0.tar.bz2       8 KB
# grpc-cpp-1.38.1-h36ce80c_0.tar.bz2           3.6 MB
# zict-2.0.0-py_0.tar.bz2                       10 KB
# distributed-2021.6.2-py38h578d9bd_0.tar.bz2     1.2 MB
# ptyprocess-0.7.0-pyhd3deb0d_0.tar.bz2         16 KB
# pyqt-5.12.3-py38h578d9bd_7.tar.bz2            21 KB
# entrypoints-0.3-pyhd8ed1ab_1003.tar.bz2        8 KB
# parso-0.8.2-pyhd8ed1ab_0.tar.bz2              68 KB
# zlib-1.2.11-h516909a_1010.tar.bz2            106 KB
# pixman-0.40.0-h36c2ea0_0.tar.bz2             627 KB
# gst-plugins-base-1.18.4-hf529b03_2.tar.bz2     2.6 MB
# libev-4.33-h516909a_1.tar.bz2                104 KB
# lerc-2.2.1-h9c3ff4c_0.tar.bz2                213 KB
# cycler-0.10.0-py_2.tar.bz2                     9 KB
# ca-certificates-2021.5.30-ha878542_0.tar.bz2     136 KB
# webencodings-0.5.1-py_1.tar.bz2               12 KB
# glib-2.68.3-h9c3ff4c_0.tar.bz2               449 KB
# pandoc-2.14.0.3-h7f98852_0.tar.bz2          12.0 MB
# async-timeout-3.0.1-py_1000.tar.bz2           11 KB
# libblas-3.9.0-9_openblas.tar.bz2              11 KB
# pyarrow-4.0.1-py38hc9229eb_2_cpu.tar.bz2     2.7 MB
# brotlipy-0.7.0-py38h497a2fe_1001.tar.bz2     341 KB
# libpng-1.6.37-h21135ba_2.tar.bz2             306 KB
# abseil-cpp-20210324.2-h9c3ff4c_0.tar.bz2    1010 KB
# nbclient-0.5.3-pyhd8ed1ab_0.tar.bz2           67 KB
# libogg-1.3.4-h7f98852_1.tar.bz2              206 KB
# xorg-kbproto-1.0.7-h7f98852_1002.tar.bz2      27 KB
# aioitertools-0.7.1-pyhd8ed1ab_0.tar.bz2       19 KB
# cryptography-3.4.7-py38ha5dfef3_0.tar.bz2     1.1 MB
# freetype-2.10.4-h0708190_1.tar.bz2           890 KB
# libffi-3.3-h58526e2_2.tar.bz2                 51 KB
# glib-tools-2.68.3-h9c3ff4c_0.tar.bz2          86 KB
# backports.functools_lru_cache-1.6.4-pyhd8ed1ab_0.tar.bz2       9 KB
# pyqtchart-5.12-py38h7400c14_7.tar.bz2        257 KB
# pandocfilters-1.4.2-py_1.tar.bz2               9 KB
# python_abi-3.8-2_cp38.tar.bz2                  4 KB
# jbig-2.1-h7f98852_2003.tar.bz2                43 KB
# lzo-2.10-h516909a_1000.tar.bz2               314 KB
# xorg-libxau-1.0.9-h7f98852_0.tar.bz2          13 KB
# cached_property-1.5.2-pyha770c72_1.tar.bz2      11 KB
# locket-0.2.0-py_2.tar.bz2                      6 KB
# pycparser-2.20-pyh9f0ad1d_2.tar.bz2           94 KB
# ipython-7.25.0-py38hd0cf306_0.tar.bz2        1.1 MB
# setuptools-49.6.0-py38h578d9bd_3.tar.bz2     929 KB
# liblapack-3.9.0-9_openblas.tar.bz2            11 KB
# matplotlib-inline-0.1.2-pyhd8ed1ab_2.tar.bz2      11 KB
# joblib-1.0.1-pyhd8ed1ab_0.tar.bz2            206 KB
# python-dateutil-2.8.1-py_0.tar.bz2           220 KB
# libnghttp2-1.43.0-h812cca2_0.tar.bz2         808 KB
# botocore-1.20.49-pyhd8ed1ab_0.tar.bz2        4.6 MB
# nodejs-14.15.4-h92b4a50_1.tar.bz2           15.7 MB
# libgomp-9.3.0-h2828fa1_19.tar.bz2            376 KB
# zipp-3.4.1-pyhd8ed1ab_0.tar.bz2               11 KB
# xorg-xextproto-7.3.0-h7f98852_1002.tar.bz2      28 KB
# aiohttp-3.7.4.post0-py38h497a2fe_0.tar.bz2     641 KB
# libclang-11.1.0-default_ha53f305_1.tar.bz2    19.2 MB
# pandas-1.2.5-py38h1abd341_0.tar.bz2         12.1 MB
# fonts-conda-ecosystem-1-0.tar.bz2              4 KB
# libuv-1.41.0-h7f98852_0.tar.bz2              1.0 MB
# nss-3.67-hb5efdd6_0.tar.bz2                  2.1 MB
# arrow-cpp-4.0.1-py38h7d5ba57_2_cpu.tar.bz2    22.2 MB
# yarl-1.6.3-py38h497a2fe_1.tar.bz2            143 KB
# llvmlite-0.36.0-py38h4630a5e_0.tar.bz2       2.8 MB
# matplotlib-3.4.2-py38h578d9bd_0.tar.bz2        7 KB
# async_generator-1.10-py_0.tar.bz2             18 KB
# libgfortran5-9.3.0-hff62375_19.tar.bz2       2.0 MB
# alsa-lib-1.2.3-h516909a_0.tar.bz2            560 KB
# xorg-libxext-1.3.4-h7f98852_1.tar.bz2         54 KB
# xorg-renderproto-0.11.1-h7f98852_1002.tar.bz2       9 KB
# pillow-8.2.0-py38ha0e1e83_1.tar.bz2          688 KB
# aws-sdk-cpp-1.8.186-hb4091e7_3.tar.bz2       4.6 MB
# importlib-metadata-4.6.0-py38h578d9bd_0.tar.bz2      31 KB
# jupyter_core-4.7.1-py38h578d9bd_0.tar.bz2      72 KB
# jsonschema-3.2.0-pyhd8ed1ab_3.tar.bz2         45 KB
# xorg-libsm-1.2.3-hd9c2040_1000.tar.bz2        26 KB
# argon2-cffi-20.1.0-py38h497a2fe_2.tar.bz2      48 KB
# dask-labextension-5.0.2-pyhd8ed1ab_0.tar.bz2      38 KB
# jmespath-0.10.0-pyh9f0ad1d_0.tar.bz2          21 KB
# backports-1.0-py_2.tar.bz2                     4 KB
# libevent-2.1.10-hcdb4288_3.tar.bz2           1.1 MB
# pip-21.1.3-pyhd8ed1ab_0.tar.bz2              1.1 MB
# libopenblas-0.3.15-pthreads_h8fe5266_1.tar.bz2     9.2 MB
# requests-unixsocket-0.2.0-py_0.tar.bz2        14 KB
# libxml2-2.9.12-h72842e0_0.tar.bz2            772 KB
# graphviz-2.47.3-h85b4f2f_0.tar.bz2           4.0 MB
# giflib-5.2.1-h36c2ea0_2.tar.bz2               77 KB
# multidict-5.1.0-py38h497a2fe_1.tar.bz2        68 KB
# font-ttf-source-code-pro-2.038-h77eed37_0.tar.bz2     684 KB
# fribidi-1.0.10-h36c2ea0_0.tar.bz2            112 KB
# libpq-13.3-hd57d9b9_0.tar.bz2                2.7 MB
# pyparsing-2.4.7-pyh9f0ad1d_0.tar.bz2          60 KB
# kiwisolver-1.3.1-py38h1fd1430_1.tar.bz2       80 KB
# cytoolz-0.11.0-py38h497a2fe_3.tar.bz2        420 KB
# idna-2.10-pyh9f0ad1d_0.tar.bz2                52 KB
# yaml-0.2.5-h516909a_0.tar.bz2                 82 KB
# libtiff-4.3.0-hf544144_1.tar.bz2             668 KB
# re2-2021.06.01-h9c3ff4c_0.tar.bz2            218 KB
# pysocks-1.7.1-py38h578d9bd_3.tar.bz2          27 KB
# pyqt-impl-5.12.3-py38h7400c14_7.tar.bz2      5.9 MB
# libllvm10-10.0.1-he513fc3_3.tar.bz2         26.4 MB
# anyio-3.2.1-py38h578d9bd_0.tar.bz2           139 KB
# sortedcontainers-2.4.0-pyhd8ed1ab_0.tar.bz2      26 KB
# babel-2.9.1-pyh44b312d_0.tar.bz2             6.2 MB
# dask-glm-0.2.0-py_1.tar.bz2                   14 KB
# coiled-0.0.39.1-pyhd8ed1ab_0.tar.bz2          53 KB
# expat-2.4.1-h9c3ff4c_0.tar.bz2               182 KB
# gettext-0.19.8.1-h0b5b191_1005.tar.bz2       3.6 MB
# ld_impl_linux-64-2.35.1-hea4e1c9_2.tar.bz2     618 KB
# attrs-21.2.0-pyhd8ed1ab_0.tar.bz2             44 KB
# gts-0.7.6-h64030ff_2.tar.bz2                 411 KB
# _openmp_mutex-4.5-1_gnu.tar.bz2               22 KB
# sqlite-3.36.0-h9cd32fc_0.tar.bz2             1.4 MB
# cloudpickle-1.6.0-py_0.tar.bz2                22 KB
# ipykernel-5.5.5-py38hd0cf306_0.tar.bz2       167 KB
# pyopenssl-20.0.1-pyhd8ed1ab_0.tar.bz2         48 KB
# libdeflate-1.7-h7f98852_5.tar.bz2             67 KB
# decorator-5.0.9-pyhd8ed1ab_0.tar.bz2          11 KB
# hdf5-1.10.6-nompi_h6a2412b_1114.tar.bz2      3.1 MB
# mistune-0.8.4-py38h497a2fe_1004.tar.bz2       54 KB
# pango-1.48.5-hb8ff022_0.tar.bz2              398 KB
# libstdcxx-ng-9.3.0-h6de172a_19.tar.bz2       4.0 MB
# jupyter_server-1.9.0-pyhd8ed1ab_0.tar.bz2     262 KB
# libedit-3.1.20191231-he28a2e2_2.tar.bz2      121 KB
# pcre-8.45-h9c3ff4c_0.tar.bz2                 253 KB
# jpeg-9d-h36c2ea0_0.tar.bz2                   264 KB
# bokeh-2.3.2-py38h578d9bd_0.tar.bz2           8.2 MB
# lcms2-2.12-hddcbb42_0.tar.bz2                443 KB
# tk-8.6.10-h21135ba_1.tar.bz2                 3.2 MB
# threadpoolctl-2.1.0-pyh5ca1d4c_0.tar.bz2      15 KB
# libgd-2.3.2-h78a0170_0.tar.bz2               299 KB
# typing_extensions-3.10.0.0-pyha770c72_0.tar.bz2      28 KB
# lz4-c-1.9.3-h9c3ff4c_0.tar.bz2               179 KB
# libprotobuf-3.16.0-h780b84a_0.tar.bz2        2.5 MB
# libvorbis-1.3.7-h9c3ff4c_0.tar.bz2           280 KB
# urllib3-1.26.6-pyhd8ed1ab_0.tar.bz2           99 KB
# wcwidth-0.2.5-pyh9f0ad1d_2.tar.bz2            33 KB
# python-3.8.10-h49503c6_1_cpython.tar.bz2    26.2 MB
# notebook-6.4.0-pyha770c72_0.tar.bz2          6.1 MB
# jupyterlab_server-2.6.0-pyhd8ed1ab_0.tar.bz2      44 KB
# send2trash-1.7.1-pyhd8ed1ab_0.tar.bz2         17 KB
# mock-4.0.3-py38h578d9bd_1.tar.bz2             51 KB
# gflags-2.2.2-he1b5a44_1004.tar.bz2           114 KB
# libsodium-1.0.18-h36c2ea0_1.tar.bz2          366 KB
# aws-c-event-stream-0.2.7-h3541f99_13.tar.bz2      47 KB
# backcall-0.2.0-pyh9f0ad1d_0.tar.bz2           13 KB
# aiobotocore-1.3.1-pyhd8ed1ab_0.tar.bz2        40 KB
# libxcb-1.13-h7f98852_1003.tar.bz2            395 KB
# xorg-xproto-7.0.31-h7f98852_1007.tar.bz2      73 KB
# gtk2-2.24.33-h539f30e_1.tar.bz2              7.3 MB
# font-ttf-inconsolata-3.000-h77eed37_0.tar.bz2      94 KB
# json5-0.9.5-pyh9f0ad1d_0.tar.bz2              20 KB
# harfbuzz-2.8.1-h83ec7ef_0.tar.bz2            1.9 MB
# traitlets-5.0.5-py_0.tar.bz2                  81 KB
# brotli-1.0.9-h9c3ff4c_4.tar.bz2              389 KB
# font-ttf-dejavu-sans-mono-2.37-hab24e00_0.tar.bz2     388 KB
# mysql-libs-8.0.25-hfa10184_2.tar.bz2         1.8 MB
# defusedxml-0.7.1-pyhd8ed1ab_0.tar.bz2         23 KB
# matplotlib-base-3.4.2-py38hcc49a3a_0.tar.bz2     7.2 MB
# gstreamer-1.18.4-h76c114f_2.tar.bz2          2.0 MB
# numpy-1.21.0-py38h9894fe3_0.tar.bz2          6.2 MB
# jupyterlab-3.0.16-pyhd8ed1ab_0.tar.bz2       5.7 MB
# jinja2-3.0.1-pyhd8ed1ab_0.tar.bz2             99 KB
# libtool-2.4.6-h58526e2_1007.tar.bz2          497 KB
# libthrift-0.14.2-he6d91bd_1.tar.bz2          4.5 MB
# tblib-1.7.0-pyhd8ed1ab_0.tar.bz2              15 KB
# libiconv-1.16-h516909a_0.tar.bz2             1.4 MB
# libcurl-7.77.0-h2574ce0_0.tar.bz2            334 KB
# aws-checksums-0.1.11-ha31a3da_7.tar.bz2       50 KB
# xorg-libx11-1.7.2-h7f98852_0.tar.bz2         941 KB
# zstd-1.5.0-ha95c52a_0.tar.bz2                490 KB
# pytables-3.6.1-py38hc386592_3.tar.bz2        1.5 MB
# s3transfer-0.3.7-pyhd8ed1ab_0.tar.bz2         51 KB
# olefile-0.46-pyh9f0ad1d_1.tar.bz2             32 KB
# font-ttf-ubuntu-0.83-hab24e00_0.tar.bz2      1.9 MB
# aws-c-common-0.6.2-h7f98852_0.tar.bz2        168 KB
# requests-2.25.1-pyhd3deb0d_0.tar.bz2          51 KB
# nbconvert-6.1.0-py38h578d9bd_0.tar.bz2       521 KB
# libssh2-1.9.0-ha56f1ee_6.tar.bz2             226 KB
# websocket-client-0.57.0-py38h578d9bd_4.tar.bz2      59 KB
# nomkl-1.0-h5ca1d4c_0.tar.bz2                   4 KB
# six-1.16.0-pyh6c4a22f_0.tar.bz2               14 KB
# numexpr-2.7.3-py38h51da96c_0.tar.bz2         201 KB
# packaging-20.9-pyh44b312d_0.tar.bz2           35 KB
# boto3-1.17.49-pyhd8ed1ab_0.tar.bz2            70 KB
# wheel-0.36.2-pyhd3deb0d_0.tar.bz2             31 KB
# libglib-2.68.3-h3e27bee_0.tar.bz2            3.1 MB
# jupyter_client-6.1.12-pyhd8ed1ab_0.tar.bz2      79 KB
# dask-ml-1.9.0-pyhd8ed1ab_0.tar.bz2           101 KB
# nest-asyncio-1.5.1-pyhd8ed1ab_0.tar.bz2        9 KB
# typing-extensions-3.10.0.0-hd8ed1ab_0.tar.bz2       8 KB
# cffi-1.14.5-py38ha65f79e_0.tar.bz2           227 KB
# dask-core-2021.6.2-pyhd8ed1ab_0.tar.bz2      743 KB
# cairo-1.16.0-h6cf1ce9_1008.tar.bz2           1.5 MB
# xz-5.2.5-h516909a_1.tar.bz2                  343 KB
# markupsafe-2.0.1-py38h497a2fe_0.tar.bz2       22 KB
# graphite2-1.3.13-h58526e2_1001.tar.bz2       102 KB
# libcblas-3.9.0-9_openblas.tar.bz2             11 KB
# ipython_genutils-0.2.0-py_1.tar.bz2           21 KB
# simpervisor-0.4-pyhd8ed1ab_0.tar.bz2           9 KB
# c-ares-1.17.1-h7f98852_1.tar.bz2             109 KB
# scipy-1.7.0-py38h7b17777_0.tar.bz2          21.9 MB
# sniffio-1.2.0-py38h578d9bd_1.tar.bz2          15 KB
# parquet-cpp-1.5.1-2.tar.bz2                    3 KB
# jupyter-server-proxy-3.0.2-pyhd8ed1ab_0.tar.bz2      27 KB
# blosc-1.21.0-h9c3ff4c_0.tar.bz2              841 KB
# certifi-2021.5.30-py38h578d9bd_0.tar.bz2     141 KB
# xorg-libxdmcp-1.1.3-h7f98852_0.tar.bz2        19 KB
# multipledispatch-0.6.0-py_0.tar.bz2           12 KB
# prometheus_client-0.11.0-pyhd8ed1ab_0.tar.bz2      46 KB
# orc-1.6.8-h58a87f1_0.tar.bz2                 740 KB
# commonmark-0.9.1-py_0.tar.bz2                 46 KB
# bleach-3.3.0-pyh44b312d_0.tar.bz2            111 KB
# icu-68.1-h58526e2_0.tar.bz2                 13.0 MB
# fontconfig-2.13.1-hba837de_1005.tar.bz2      357 KB
# msgpack-python-1.0.2-py38h1fd1430_1.tar.bz2      92 KB
# pytz-2021.1-pyhd8ed1ab_0.tar.bz2             239 KB
# partd-1.2.0-pyhd8ed1ab_0.tar.bz2              18 KB
# aws-c-io-0.10.5-hfb6a706_0.tar.bz2           121 KB
# libllvm11-11.1.0-hf817b99_2.tar.bz2         29.1 MB
# tornado-6.1-py38h497a2fe_1.tar.bz2           649 KB
# libgfortran-ng-9.3.0-hff62375_19.tar.bz2      22 KB
# cached-property-1.5.2-hd8ed1ab_1.tar.bz2       4 KB
# libxkbcommon-1.0.3-he3ba5ed_0.tar.bz2        581 KB
# chardet-4.0.0-py38h578d9bd_1.tar.bz2         199 KB
# pygments-2.9.0-pyhd8ed1ab_0.tar.bz2          754 KB
# python-graphviz-0.16-pyh243d235_2.tar.bz2      20 KB
# nbserverproxy-0.8.8-py_1000.tar.bz2           10 KB
# pyyaml-5.4.1-py38h497a2fe_0.tar.bz2          192 KB
# aws-c-cal-0.5.11-h95a6274_0.tar.bz2           37 KB
# heapdict-1.0.1-py_0.tar.bz2                    7 KB
# colorama-0.4.4-pyh9f0ad1d_0.tar.bz2           18 KB
#
# ---------------------------------------------------
# Total:                                     518.7 MB
#
# Removed openjpeg-2.4.0-hb52868f_1.tar.bz2
# Removed xorg-libxrender-0.9.10-h7f98852_1003.tar.bz2
# Removed nbformat-5.1.3-pyhd8ed1ab_0.tar.bz2
# Removed _libgcc_mutex-0.1-conda_forge.tar.bz2
# Removed pyqt5-sip-4.19.18-py38h709712a_7.tar.bz2
# Removed xorg-libice-1.0.10-h7f98852_0.tar.bz2
# Removed click-8.0.1-py38h578d9bd_0.tar.bz2
# Removed pexpect-4.8.0-pyh9f0ad1d_2.tar.bz2
# Removed mysql-common-8.0.25-ha770c72_2.tar.bz2
# Removed zeromq-4.3.4-h9c3ff4c_0.tar.bz2
# Removed psutil-5.8.0-py38h497a2fe_1.tar.bz2
# Removed ncurses-6.2-h58526e2_4.tar.bz2
# Removed libuuid-2.32.1-h7f98852_1000.tar.bz2
# Removed openssl-1.1.1k-h7f98852_0.tar.bz2
# Removed libwebp-base-1.2.0-h7f98852_2.tar.bz2
# Removed terminado-0.10.1-py38h578d9bd_0.tar.bz2
# Removed krb5-1.19.1-hcc1bbae_0.tar.bz2
# Removed libwebp-1.2.0-h3452ae3_0.tar.bz2
# Removed fsspec-2021.6.1-pyhd8ed1ab_0.tar.bz2
# Removed wrapt-1.12.1-py38h497a2fe_3.tar.bz2
# Removed jedi-0.18.0-py38h578d9bd_2.tar.bz2
# Removed testpath-0.5.0-pyhd8ed1ab_0.tar.bz2
# Removed libopus-1.3.1-h7f98852_1.tar.bz2
# Removed atk-1.0-2.36.0-h3371d22_4.tar.bz2
# Removed librsvg-2.50.7-hc3c00ef_0.tar.bz2
# Removed pthread-stubs-0.4-h36c2ea0_1001.tar.bz2
# Removed qt-5.12.9-hda022c4_4.tar.bz2
# Removed snappy-1.1.8-he1b5a44_3.tar.bz2
# Removed prompt-toolkit-3.0.19-pyha770c72_0.tar.bz2
# Removed bzip2-1.0.8-h7f98852_4.tar.bz2
# Removed toolz-0.11.1-py_0.tar.bz2
# Removed h5py-3.3.0-nompi_py38h9915d05_100.tar.bz2
# Removed rich-10.4.0-py38h578d9bd_0.tar.bz2
# Removed pyrsistent-0.17.3-py38h497a2fe_2.tar.bz2
# Removed s3fs-2021.6.1-pyhd8ed1ab_0.tar.bz2
# Removed libgcc-ng-9.3.0-h2828fa1_19.tar.bz2
# Removed libutf8proc-2.6.1-h7f98852_0.tar.bz2
# Removed scikit-learn-0.24.2-py38hdc147b9_0.tar.bz2
# Removed pyqtwebengine-5.12.1-py38h7400c14_7.tar.bz2
# Removed readline-8.1-h46c0cb4_0.tar.bz2
# Removed nbclassic-0.3.1-pyhd8ed1ab_1.tar.bz2
# Removed pickleshare-0.7.5-py_1003.tar.bz2
# Removed dask-2021.6.2-pyhd8ed1ab_0.tar.bz2
# Removed fonts-conda-forge-1-0.tar.bz2
# Removed nspr-4.30-h9c3ff4c_0.tar.bz2
# Removed future-0.18.2-py38h578d9bd_3.tar.bz2
# Removed s2n-1.0.10-h9b69904_0.tar.bz2
# Removed pyzmq-22.1.0-py38h2035c66_0.tar.bz2
# Removed glog-0.5.0-h48cff8f_0.tar.bz2
# Removed dbus-1.13.6-h48d8840_2.tar.bz2
# Removed numba-0.53.1-py38h8b71fd7_1.tar.bz2
# Removed gdk-pixbuf-2.42.6-h04a7f16_0.tar.bz2
# Removed jupyterlab_pygments-0.1.2-pyh9f0ad1d_0.tar.bz2
# Removed grpc-cpp-1.38.1-h36ce80c_0.tar.bz2
# Removed zict-2.0.0-py_0.tar.bz2
# Removed distributed-2021.6.2-py38h578d9bd_0.tar.bz2
# Removed ptyprocess-0.7.0-pyhd3deb0d_0.tar.bz2
# Removed pyqt-5.12.3-py38h578d9bd_7.tar.bz2
# Removed entrypoints-0.3-pyhd8ed1ab_1003.tar.bz2
# Removed parso-0.8.2-pyhd8ed1ab_0.tar.bz2
# Removed zlib-1.2.11-h516909a_1010.tar.bz2
# Removed pixman-0.40.0-h36c2ea0_0.tar.bz2
# Removed gst-plugins-base-1.18.4-hf529b03_2.tar.bz2
# Removed libev-4.33-h516909a_1.tar.bz2
# Removed lerc-2.2.1-h9c3ff4c_0.tar.bz2
# Removed cycler-0.10.0-py_2.tar.bz2
# Removed ca-certificates-2021.5.30-ha878542_0.tar.bz2
# Removed webencodings-0.5.1-py_1.tar.bz2
# Removed glib-2.68.3-h9c3ff4c_0.tar.bz2
# Removed pandoc-2.14.0.3-h7f98852_0.tar.bz2
# Removed async-timeout-3.0.1-py_1000.tar.bz2
# Removed libblas-3.9.0-9_openblas.tar.bz2
# Removed pyarrow-4.0.1-py38hc9229eb_2_cpu.tar.bz2
# Removed brotlipy-0.7.0-py38h497a2fe_1001.tar.bz2
# Removed libpng-1.6.37-h21135ba_2.tar.bz2
# Removed abseil-cpp-20210324.2-h9c3ff4c_0.tar.bz2
# Removed nbclient-0.5.3-pyhd8ed1ab_0.tar.bz2
# Removed libogg-1.3.4-h7f98852_1.tar.bz2
# Removed xorg-kbproto-1.0.7-h7f98852_1002.tar.bz2
# Removed aioitertools-0.7.1-pyhd8ed1ab_0.tar.bz2
# Removed cryptography-3.4.7-py38ha5dfef3_0.tar.bz2
# Removed freetype-2.10.4-h0708190_1.tar.bz2
# Removed libffi-3.3-h58526e2_2.tar.bz2
# Removed glib-tools-2.68.3-h9c3ff4c_0.tar.bz2
# Removed backports.functools_lru_cache-1.6.4-pyhd8ed1ab_0.tar.bz2
# Removed pyqtchart-5.12-py38h7400c14_7.tar.bz2
# Removed pandocfilters-1.4.2-py_1.tar.bz2
# Removed python_abi-3.8-2_cp38.tar.bz2
# Removed jbig-2.1-h7f98852_2003.tar.bz2
# Removed lzo-2.10-h516909a_1000.tar.bz2
# Removed xorg-libxau-1.0.9-h7f98852_0.tar.bz2
# Removed cached_property-1.5.2-pyha770c72_1.tar.bz2
# Removed locket-0.2.0-py_2.tar.bz2
# Removed pycparser-2.20-pyh9f0ad1d_2.tar.bz2
# Removed ipython-7.25.0-py38hd0cf306_0.tar.bz2
# Removed setuptools-49.6.0-py38h578d9bd_3.tar.bz2
# Removed liblapack-3.9.0-9_openblas.tar.bz2
# Removed matplotlib-inline-0.1.2-pyhd8ed1ab_2.tar.bz2
# Removed joblib-1.0.1-pyhd8ed1ab_0.tar.bz2
# Removed python-dateutil-2.8.1-py_0.tar.bz2
# Removed libnghttp2-1.43.0-h812cca2_0.tar.bz2
# Removed botocore-1.20.49-pyhd8ed1ab_0.tar.bz2
# Removed nodejs-14.15.4-h92b4a50_1.tar.bz2
# Removed libgomp-9.3.0-h2828fa1_19.tar.bz2
# Removed zipp-3.4.1-pyhd8ed1ab_0.tar.bz2
# Removed xorg-xextproto-7.3.0-h7f98852_1002.tar.bz2
# Removed aiohttp-3.7.4.post0-py38h497a2fe_0.tar.bz2
# Removed libclang-11.1.0-default_ha53f305_1.tar.bz2
# Removed pandas-1.2.5-py38h1abd341_0.tar.bz2
# Removed fonts-conda-ecosystem-1-0.tar.bz2
# Removed libuv-1.41.0-h7f98852_0.tar.bz2
# Removed nss-3.67-hb5efdd6_0.tar.bz2
# Removed arrow-cpp-4.0.1-py38h7d5ba57_2_cpu.tar.bz2
# Removed yarl-1.6.3-py38h497a2fe_1.tar.bz2
# Removed llvmlite-0.36.0-py38h4630a5e_0.tar.bz2
# Removed matplotlib-3.4.2-py38h578d9bd_0.tar.bz2
# Removed async_generator-1.10-py_0.tar.bz2
# Removed libgfortran5-9.3.0-hff62375_19.tar.bz2
# Removed alsa-lib-1.2.3-h516909a_0.tar.bz2
# Removed xorg-libxext-1.3.4-h7f98852_1.tar.bz2
# Removed xorg-renderproto-0.11.1-h7f98852_1002.tar.bz2
# Removed pillow-8.2.0-py38ha0e1e83_1.tar.bz2
# Removed aws-sdk-cpp-1.8.186-hb4091e7_3.tar.bz2
# Removed importlib-metadata-4.6.0-py38h578d9bd_0.tar.bz2
# Removed jupyter_core-4.7.1-py38h578d9bd_0.tar.bz2
# Removed jsonschema-3.2.0-pyhd8ed1ab_3.tar.bz2
# Removed xorg-libsm-1.2.3-hd9c2040_1000.tar.bz2
# Removed argon2-cffi-20.1.0-py38h497a2fe_2.tar.bz2
# Removed dask-labextension-5.0.2-pyhd8ed1ab_0.tar.bz2
# Removed jmespath-0.10.0-pyh9f0ad1d_0.tar.bz2
# Removed backports-1.0-py_2.tar.bz2
# Removed libevent-2.1.10-hcdb4288_3.tar.bz2
# Removed pip-21.1.3-pyhd8ed1ab_0.tar.bz2
# Removed libopenblas-0.3.15-pthreads_h8fe5266_1.tar.bz2
# Removed requests-unixsocket-0.2.0-py_0.tar.bz2
# Removed libxml2-2.9.12-h72842e0_0.tar.bz2
# Removed graphviz-2.47.3-h85b4f2f_0.tar.bz2
# Removed giflib-5.2.1-h36c2ea0_2.tar.bz2
# Removed multidict-5.1.0-py38h497a2fe_1.tar.bz2
# Removed font-ttf-source-code-pro-2.038-h77eed37_0.tar.bz2
# Removed fribidi-1.0.10-h36c2ea0_0.tar.bz2
# Removed libpq-13.3-hd57d9b9_0.tar.bz2
# Removed pyparsing-2.4.7-pyh9f0ad1d_0.tar.bz2
# Removed kiwisolver-1.3.1-py38h1fd1430_1.tar.bz2
# Removed cytoolz-0.11.0-py38h497a2fe_3.tar.bz2
# Removed idna-2.10-pyh9f0ad1d_0.tar.bz2
# Removed yaml-0.2.5-h516909a_0.tar.bz2
# Removed libtiff-4.3.0-hf544144_1.tar.bz2
# Removed re2-2021.06.01-h9c3ff4c_0.tar.bz2
# Removed pysocks-1.7.1-py38h578d9bd_3.tar.bz2
# Removed pyqt-impl-5.12.3-py38h7400c14_7.tar.bz2
# Removed libllvm10-10.0.1-he513fc3_3.tar.bz2
# Removed anyio-3.2.1-py38h578d9bd_0.tar.bz2
# Removed sortedcontainers-2.4.0-pyhd8ed1ab_0.tar.bz2
# Removed babel-2.9.1-pyh44b312d_0.tar.bz2
# Removed dask-glm-0.2.0-py_1.tar.bz2
# Removed coiled-0.0.39.1-pyhd8ed1ab_0.tar.bz2
# Removed expat-2.4.1-h9c3ff4c_0.tar.bz2
# Removed gettext-0.19.8.1-h0b5b191_1005.tar.bz2
# Removed ld_impl_linux-64-2.35.1-hea4e1c9_2.tar.bz2
# Removed attrs-21.2.0-pyhd8ed1ab_0.tar.bz2
# Removed gts-0.7.6-h64030ff_2.tar.bz2
# Removed _openmp_mutex-4.5-1_gnu.tar.bz2
# Removed sqlite-3.36.0-h9cd32fc_0.tar.bz2
# Removed cloudpickle-1.6.0-py_0.tar.bz2
# Removed ipykernel-5.5.5-py38hd0cf306_0.tar.bz2
# Removed pyopenssl-20.0.1-pyhd8ed1ab_0.tar.bz2
# Removed libdeflate-1.7-h7f98852_5.tar.bz2
# Removed decorator-5.0.9-pyhd8ed1ab_0.tar.bz2
# Removed hdf5-1.10.6-nompi_h6a2412b_1114.tar.bz2
# Removed mistune-0.8.4-py38h497a2fe_1004.tar.bz2
# Removed pango-1.48.5-hb8ff022_0.tar.bz2
# Removed libstdcxx-ng-9.3.0-h6de172a_19.tar.bz2
# Removed jupyter_server-1.9.0-pyhd8ed1ab_0.tar.bz2
# Removed libedit-3.1.20191231-he28a2e2_2.tar.bz2
# Removed pcre-8.45-h9c3ff4c_0.tar.bz2
# Removed jpeg-9d-h36c2ea0_0.tar.bz2
# Removed bokeh-2.3.2-py38h578d9bd_0.tar.bz2
# Removed lcms2-2.12-hddcbb42_0.tar.bz2
# Removed tk-8.6.10-h21135ba_1.tar.bz2
# Removed threadpoolctl-2.1.0-pyh5ca1d4c_0.tar.bz2
# Removed libgd-2.3.2-h78a0170_0.tar.bz2
# Removed typing_extensions-3.10.0.0-pyha770c72_0.tar.bz2
# Removed lz4-c-1.9.3-h9c3ff4c_0.tar.bz2
# Removed libprotobuf-3.16.0-h780b84a_0.tar.bz2
# Removed libvorbis-1.3.7-h9c3ff4c_0.tar.bz2
# Removed urllib3-1.26.6-pyhd8ed1ab_0.tar.bz2
# Removed wcwidth-0.2.5-pyh9f0ad1d_2.tar.bz2
# Removed python-3.8.10-h49503c6_1_cpython.tar.bz2
# Removed notebook-6.4.0-pyha770c72_0.tar.bz2
# Removed jupyterlab_server-2.6.0-pyhd8ed1ab_0.tar.bz2
# Removed send2trash-1.7.1-pyhd8ed1ab_0.tar.bz2
# Removed mock-4.0.3-py38h578d9bd_1.tar.bz2
# Removed gflags-2.2.2-he1b5a44_1004.tar.bz2
# Removed libsodium-1.0.18-h36c2ea0_1.tar.bz2
# Removed aws-c-event-stream-0.2.7-h3541f99_13.tar.bz2
# Removed backcall-0.2.0-pyh9f0ad1d_0.tar.bz2
# Removed aiobotocore-1.3.1-pyhd8ed1ab_0.tar.bz2
# Removed libxcb-1.13-h7f98852_1003.tar.bz2
# Removed xorg-xproto-7.0.31-h7f98852_1007.tar.bz2
# Removed gtk2-2.24.33-h539f30e_1.tar.bz2
# Removed font-ttf-inconsolata-3.000-h77eed37_0.tar.bz2
# Removed json5-0.9.5-pyh9f0ad1d_0.tar.bz2
# Removed harfbuzz-2.8.1-h83ec7ef_0.tar.bz2
# Removed traitlets-5.0.5-py_0.tar.bz2
# Removed brotli-1.0.9-h9c3ff4c_4.tar.bz2
# Removed font-ttf-dejavu-sans-mono-2.37-hab24e00_0.tar.bz2
# Removed mysql-libs-8.0.25-hfa10184_2.tar.bz2
# Removed defusedxml-0.7.1-pyhd8ed1ab_0.tar.bz2
# Removed matplotlib-base-3.4.2-py38hcc49a3a_0.tar.bz2
# Removed gstreamer-1.18.4-h76c114f_2.tar.bz2
# Removed numpy-1.21.0-py38h9894fe3_0.tar.bz2
# Removed jupyterlab-3.0.16-pyhd8ed1ab_0.tar.bz2
# Removed jinja2-3.0.1-pyhd8ed1ab_0.tar.bz2
# Removed libtool-2.4.6-h58526e2_1007.tar.bz2
# Removed libthrift-0.14.2-he6d91bd_1.tar.bz2
# Removed tblib-1.7.0-pyhd8ed1ab_0.tar.bz2
# Removed libiconv-1.16-h516909a_0.tar.bz2
# Removed libcurl-7.77.0-h2574ce0_0.tar.bz2
# Removed aws-checksums-0.1.11-ha31a3da_7.tar.bz2
# Removed xorg-libx11-1.7.2-h7f98852_0.tar.bz2
# Removed zstd-1.5.0-ha95c52a_0.tar.bz2
# Removed pytables-3.6.1-py38hc386592_3.tar.bz2
# Removed s3transfer-0.3.7-pyhd8ed1ab_0.tar.bz2
# Removed olefile-0.46-pyh9f0ad1d_1.tar.bz2
# Removed font-ttf-ubuntu-0.83-hab24e00_0.tar.bz2
# Removed aws-c-common-0.6.2-h7f98852_0.tar.bz2
# Removed requests-2.25.1-pyhd3deb0d_0.tar.bz2
# Removed nbconvert-6.1.0-py38h578d9bd_0.tar.bz2
# Removed libssh2-1.9.0-ha56f1ee_6.tar.bz2
# Removed websocket-client-0.57.0-py38h578d9bd_4.tar.bz2
# Removed nomkl-1.0-h5ca1d4c_0.tar.bz2
# Removed six-1.16.0-pyh6c4a22f_0.tar.bz2
# Removed numexpr-2.7.3-py38h51da96c_0.tar.bz2
# Removed packaging-20.9-pyh44b312d_0.tar.bz2
# Removed boto3-1.17.49-pyhd8ed1ab_0.tar.bz2
# Removed wheel-0.36.2-pyhd3deb0d_0.tar.bz2
# Removed libglib-2.68.3-h3e27bee_0.tar.bz2
# Removed jupyter_client-6.1.12-pyhd8ed1ab_0.tar.bz2
# Removed dask-ml-1.9.0-pyhd8ed1ab_0.tar.bz2
# Removed nest-asyncio-1.5.1-pyhd8ed1ab_0.tar.bz2
# Removed typing-extensions-3.10.0.0-hd8ed1ab_0.tar.bz2
# Removed cffi-1.14.5-py38ha65f79e_0.tar.bz2
# Removed dask-core-2021.6.2-pyhd8ed1ab_0.tar.bz2
# Removed cairo-1.16.0-h6cf1ce9_1008.tar.bz2
# Removed xz-5.2.5-h516909a_1.tar.bz2
# Removed markupsafe-2.0.1-py38h497a2fe_0.tar.bz2
# Removed graphite2-1.3.13-h58526e2_1001.tar.bz2
# Removed libcblas-3.9.0-9_openblas.tar.bz2
# Removed ipython_genutils-0.2.0-py_1.tar.bz2
# Removed simpervisor-0.4-pyhd8ed1ab_0.tar.bz2
# Removed c-ares-1.17.1-h7f98852_1.tar.bz2
# Removed scipy-1.7.0-py38h7b17777_0.tar.bz2
# Removed sniffio-1.2.0-py38h578d9bd_1.tar.bz2
# Removed parquet-cpp-1.5.1-2.tar.bz2
# Removed jupyter-server-proxy-3.0.2-pyhd8ed1ab_0.tar.bz2
# Removed blosc-1.21.0-h9c3ff4c_0.tar.bz2
# Removed certifi-2021.5.30-py38h578d9bd_0.tar.bz2
# Removed xorg-libxdmcp-1.1.3-h7f98852_0.tar.bz2
# Removed multipledispatch-0.6.0-py_0.tar.bz2
# Removed prometheus_client-0.11.0-pyhd8ed1ab_0.tar.bz2
# Removed orc-1.6.8-h58a87f1_0.tar.bz2
# Removed commonmark-0.9.1-py_0.tar.bz2
# Removed bleach-3.3.0-pyh44b312d_0.tar.bz2
# Removed icu-68.1-h58526e2_0.tar.bz2
# Removed fontconfig-2.13.1-hba837de_1005.tar.bz2
# Removed msgpack-python-1.0.2-py38h1fd1430_1.tar.bz2
# Removed pytz-2021.1-pyhd8ed1ab_0.tar.bz2
# Removed partd-1.2.0-pyhd8ed1ab_0.tar.bz2
# Removed aws-c-io-0.10.5-hfb6a706_0.tar.bz2
# Removed libllvm11-11.1.0-hf817b99_2.tar.bz2
# Removed tornado-6.1-py38h497a2fe_1.tar.bz2
# Removed libgfortran-ng-9.3.0-hff62375_19.tar.bz2
# Removed cached-property-1.5.2-hd8ed1ab_1.tar.bz2
# Removed libxkbcommon-1.0.3-he3ba5ed_0.tar.bz2
# Removed chardet-4.0.0-py38h578d9bd_1.tar.bz2
# Removed pygments-2.9.0-pyhd8ed1ab_0.tar.bz2
# Removed python-graphviz-0.16-pyh243d235_2.tar.bz2
# Removed nbserverproxy-0.8.8-py_1000.tar.bz2
# Removed pyyaml-5.4.1-py38h497a2fe_0.tar.bz2
# Removed aws-c-cal-0.5.11-h95a6274_0.tar.bz2
# Removed heapdict-1.0.1-py_0.tar.bz2
# Removed colorama-0.4.4-pyh9f0ad1d_0.tar.bz2
# WARNING: /root/.conda/pkgs does not exist
# Cache location: /opt/conda/pkgs
# Will remove the following packages:
# /opt/conda/pkgs
# ---------------
#
# _libgcc_mutex-0.1-conda_forge                  6 KB
# pthread-stubs-0.4-h36c2ea0_1001               14 KB
# dask-2021.6.2-pyhd8ed1ab_0                    11 KB
# fonts-conda-forge-1-0                         11 KB
# pyqt-5.12.3-py38h578d9bd_7                    79 KB
# libblas-3.9.0-9_openblas                      42 KB
# python_abi-3.8-2_cp38                         11 KB
# liblapack-3.9.0-9_openblas                    41 KB
# fonts-conda-ecosystem-1-0                      9 KB
# matplotlib-3.4.2-py38h578d9bd_0               19 KB
# _openmp_mutex-4.5-1_gnu                       93 KB
# mysql-libs-8.0.25-hfa10184_2                 6.9 MB
# nomkl-1.0-h5ca1d4c_0                           9 KB
# typing-extensions-3.10.0.0-hd8ed1ab_0         23 KB
# libcblas-3.9.0-9_openblas                     41 KB
# parquet-cpp-1.5.1-2                            8 KB
# libgfortran-ng-9.3.0-hff62375_19              92 KB
# cached-property-1.5.2-hd8ed1ab_1              10 KB
#
# ---------------------------------------------------
# Total:                                       7.4 MB
#
# removing _libgcc_mutex-0.1-conda_forge
# removing pthread-stubs-0.4-h36c2ea0_1001
# removing dask-2021.6.2-pyhd8ed1ab_0
# removing fonts-conda-forge-1-0
# removing pyqt-5.12.3-py38h578d9bd_7
# removing libblas-3.9.0-9_openblas
# removing python_abi-3.8-2_cp38
# removing liblapack-3.9.0-9_openblas
# removing fonts-conda-ecosystem-1-0
# removing matplotlib-3.4.2-py38h578d9bd_0
# removing _openmp_mutex-4.5-1_gnu
# removing mysql-libs-8.0.25-hfa10184_2
# removing nomkl-1.0-h5ca1d4c_0
# removing typing-extensions-3.10.0.0-hd8ed1ab_0
# removing libcblas-3.9.0-9_openblas
# removing parquet-cpp-1.5.1-2
# removing libgfortran-ng-9.3.0-hff62375_19
# removing cached-property-1.5.2-hd8ed1ab_1
# --> 4b0b01ba2ec
# STEP 4: ENV PATH /opt/conda/envs/coiled/bin:$PATH
# --> e79e8293a88
# STEP 5: SHELL ["conda", "run", "-n", "coiled", "/bin/bash", "-c"]
# STEP 6: COMMIT 5490b723-e622-4dd8-bbc9-37711aba2604
# --> da16f003bbf
# da16f003bbf5af99631d2d543daf3a0e936758290fdd2e77941cff236a46b7ea
#
#
# ==> WARNING: A newer version of conda exists. <==
# current version: 4.9.2
# latest version: 4.10.1
#
# Please update conda by running
#
# $ conda update -n base -c defaults conda
#
#
# Docker build succeeded: 5490b723-e622-4dd8-bbc9-37711aba2604
# Getting image source signatures
# Copying blob sha256:8235e4ea013ee10c0bf0cc745dfc9a1db28394229b1f5524d96233d624598c76
# Copying blob sha256:72178e2847dcf6fb0c00411c0a3bddbc333f5966ce1a46c0b78ce965b1cd80ec
# Copying blob sha256:95586cf65be51397fa66deda7dc39e71cde778b158d00667af113db52029d2bb
# Copying blob sha256:dfef8986f350d2efb7dd633410dceac30543be620085d9819f42db7067f55f64
# Copying blob sha256:f5600c6330da7bb112776ba067a32a9c20842d6ecc8ee3289f1a713b644092f8
# Copying blob sha256:0553ab4c463e8dd22931a5deb37e8014a18cde60d6be1337f4415de56649a947
# Copying config sha256:da16f003bbf5af99631d2d543daf3a0e936758290fdd2e77941cff236a46b7ea
# Writing manifest to image destination
# Storing signatures
# Getting image source signatures
# Copying blob sha256:72178e2847dcf6fb0c00411c0a3bddbc333f5966ce1a46c0b78ce965b1cd80ec
# Copying blob sha256:dfef8986f350d2efb7dd633410dceac30543be620085d9819f42db7067f55f64
# Copying blob sha256:8235e4ea013ee10c0bf0cc745dfc9a1db28394229b1f5524d96233d624598c76
# Copying blob sha256:0553ab4c463e8dd22931a5deb37e8014a18cde60d6be1337f4415de56649a947
# Copying blob sha256:95586cf65be51397fa66deda7dc39e71cde778b158d00667af113db52029d2bb
# Copying blob sha256:f5600c6330da7bb112776ba067a32a9c20842d6ecc8ee3289f1a713b644092f8
# Copying config sha256:da16f003bbf5af99631d2d543daf3a0e936758290fdd2e77941cff236a46b7ea
# Writing manifest to image destination
# Storing signatures
# Environment created
# Successfully saved software environment build
# CPU times: user 1min 19s, sys: 6.77 s, total: 1min 25s
# Wall time: 7min 5s

# %%
# %%time 

# Control the resources of your cluster by creating a new cluster configuration
coiled.create_cluster_configuration(
    name="my-cluster-config",
    worker_memory="16 GiB",
    worker_cpu=4,
    scheduler_memory="8 GiB",
    scheduler_cpu=2,
    software="my-software-env",
)
# Out:
# Found cluster configuration 'my-cluster-config', updating this configuration...
# CPU times: user 309 ms, sys: 119 ms, total: 428 ms
# Wall time: 1.76 s

# %%
# Spin up cluster, instantiate a Client
cluster = coiled.Cluster(n_workers=10, configuration="my-cluster-config")
client = Client(cluster)
client
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# DataNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-8114c942199c> in <module>
#       1 # Spin up cluster, instantiate a Client
# ----> 2 cluster = coiled.Cluster(n_workers=10, configuration="my-cluster-config")
#       3 client = Client(cluster)
#       4 client
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/coiled/cluster.py in __init__(self, n_workers, configuration, software, worker_cpu, worker_gpu, worker_memory, worker_class, worker_options, scheduler_cpu, scheduler_memory, scheduler_class, scheduler_options, name, asynchronous, cloud, account, shutdown_on_close, backend_options, credentials, timeout)
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/coiled/cluster.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/distributed/deploy/cluster.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/distributed/utils.py in f()
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/tornado/gen.py in run(self)
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/coiled/cluster.py in _start(self)
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/coiled/cluster.py in _send_credentials(self, cloud)
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/aiobotocore/session.py in __aenter__(self)
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/aiobotocore/session.py in _create_client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config)
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/botocore/session.py in _get_internal_component(self, name)
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/botocore/session.py in get_component(self, name)
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/botocore/session.py in create_default_resolver()
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/botocore/loaders.py in _wrapper(self, *args, **kwargs)
#
# ~/miniconda3/envs/coiled-base/lib/python3.9/site-packages/botocore/loaders.py in load_data(self, name)
#
# DataNotFoundError: Unable to load data for: endpoints

# %%
import dask.dataframe as dd

# Read data into a Dask DataFrame
df = dd.read_csv(
    "s3://nyc-tlc/trip data/yellow_tripdata_2019-*.csv", 
    parse_dates=["tpep_pickup_datetime", "tpep_dropoff_datetime"],
    dtype={
        'RatecodeID': 'float64',
       'VendorID': 'float64',
       'passenger_count': 'float64',
       'payment_type': 'float64'
    },
    storage_options={"anon":True}
)
df
# Out:
# Dask DataFrame Structure:
#                 VendorID tpep_pickup_datetime tpep_dropoff_datetime passenger_count trip_distance RatecodeID store_and_fwd_flag PULocationID DOLocationID payment_type fare_amount    extra  mta_tax tip_amount tolls_amount improvement_surcharge total_amount congestion_surcharge
# npartitions=127
#                  float64       datetime64[ns]        datetime64[ns]         float64       float64    float64             object        int64        int64      float64     float64  float64  float64    float64      float64               float64      float64              float64
#                      ...                  ...                   ...             ...           ...        ...                ...          ...          ...          ...         ...      ...      ...        ...          ...                   ...          ...                  ...
# ...                  ...                  ...                   ...             ...           ...        ...                ...          ...          ...          ...         ...      ...      ...        ...          ...                   ...          ...                  ...
#                      ...                  ...                   ...             ...           ...        ...                ...          ...          ...          ...         ...      ...      ...        ...          ...                   ...          ...                  ...
#                      ...                  ...                   ...             ...           ...        ...                ...          ...          ...          ...         ...      ...      ...        ...          ...                   ...          ...                  ...
# Dask Name: read-csv, 127 tasks

# %%
# %%time

# Prepare to compute the average tip 
# as a function of the number of passengers
mean_amount = df.groupby("passenger_count").tip_amount.mean()
# Out:
# CPU times: user 16.8 ms, sys: 1.38 ms, total: 18.1 ms
# Wall time: 17.2 ms

# %%
# %%time

# Compute the average tip 
# as a function of the number of passengers
mean_amount.compute()
# Out:
# CPU times: user 1.89 s, sys: 281 ms, total: 2.17 s
# Wall time: 27.5 s
# passenger_count
# 0.0    2.122789
# 1.0    2.206790
# 2.0    2.214306
# 3.0    2.137775
# 4.0    2.023804
# 5.0    2.235441
# 6.0    2.221105
# 7.0    6.675962
# 8.0    7.111625
# 9.0    7.377822
# Name: tip_amount, dtype: float64

# %% [markdown]
# And let's not forget our basic Dask hygiene (and financial-health) practices:

# %%
# shutdown the cluster
client.shutdown()

# %% [markdown]
# **Recap:** We have
# * used Coiled to load in **all** of the NYC taxi dataset from 10+ CSVs (10 GBs) on an AWS cluster,
# * computed the average tip as a function of the number of passengers, and
# * learned a bunch about using Dask on cloud-based clusters!
